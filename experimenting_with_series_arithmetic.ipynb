# %%
import pandas as pd

s1 = pd.Series([1,2,3])
s2 = pd.Series([1,2])

s3 = s1 + s2

s3
# Out:
# 0    2.0
# 1    4.0
# 2    NaN
# dtype: float64

# %%
s1/s3
# Out:
# 0    0.5
# 1    0.5
# 2    NaN
# dtype: float64

# %%
t1 = pd.to_timedelta(pd.Series(["0:0:01","0:0:02", "0:0:03"]))
t2 = pd.to_timedelta(pd.Series(["0:0:01","0:0:02"]))

t3 = t1 + t2
t3
# Out:
# 0   0 days 00:00:02
# 1   0 days 00:00:04
# 2               NaT
# dtype: timedelta64[ns]

# %%
t1/t3
# Out:
# 0    0.5
# 1    0.5
# 2    NaN
# dtype: float64

# %%
t1-t2
# Out:
# 0   0 days
# 1   0 days
# 2      NaT
# dtype: timedelta64[ns]
