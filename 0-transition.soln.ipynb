# %% [markdown]
# Solution - extra column

# %%
# setup, copied from other notebook
A1 = 5
A2 = 6
A3 = 7
B1 = A1 + 1
B2 = A2 + 1
B3 = A3 + 1

# solution
C1 = B1 * 2
C2 = B2 * 2
C3 = B3 * 2
print(C1)
print(C2)
print(C3)
# Out:
# 12
# 14
# 16

# %% [markdown]
# Solution - built in functions

# %%
v = -6
s = "this is a string"
# print out double of whatever is stored in the variable `v`
print(v * 2)
# print out the absolute value of whatever is stored in the variable `v`
print(abs(v))
# print out the the number of characters in the variable `s`
print(len(s))
# print out the type of the values in both `v` and `s`
print(type(v))
print(type(s))
# Out:
# -12
# 6
# 16
# <class 'int'>
# <class 'str'>
